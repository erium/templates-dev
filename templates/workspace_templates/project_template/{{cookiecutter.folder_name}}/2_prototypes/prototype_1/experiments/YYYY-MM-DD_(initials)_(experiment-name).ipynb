# %%
# <halerium id="c7434fe6-abd1-4218-959c-3293e6c41296">
# Link to prototype board
# </halerium id="c7434fe6-abd1-4218-959c-3293e6c41296">

# %%
# import the current state of the prototype's module
import sys
sys.path.append("../module")
import product_module
